# %% [markdown]
# # 시각화 모듈 Seaborn (팁문화분석)

# %%
#!pip install seaborn

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# anagrams - 단어 조합 문제(애너그램)와 관련된 실험 데이터
# anscombe - Anscombe's Quartet 데이터로, 같은 평균과 분산을 가지지만 시각화하면 전혀 다른 형태가 되는 4개의 데이터셋
# attention - 실험에서 주의력(attention)이 어떻게 작용하는지 측정한 데이터
# brain_networks - 뇌 네트워크 연결과 관련된 데이터
# car_crashes - 미국 주별 교통사고와 관련된 데이터
# diamonds - 다이아몬드의 가격, 무게, 투명도 등 다양한 특성을 포함한 데이터
# dots - 점(dot)의 이동과 관련된 실험 데이터
# dowjones - 다우존스(Dow Jones) 산업평균지수 주가 데이터
# exercise - 운동 유형, 강도, 맥박 등의 데이터를 포함한 피트니스 관련 데이터
# flights - 연도별/월별 항공편 수를 나타낸 데이터 (항공 교통량 분석에 사용됨)
# fmri - fMRI(기능적 자기공명영상) 데이터를 사용하여 뇌 활성도를 나타낸 데이터
# geyser - Old Faithful 간헐천의 분출 시간 및 간격에 대한 데이터
# glue - 다양한 실험에서 사용되는 접착제(glue)와 관련된 데이터
# healthexp - 국가별 건강 관련 지출 및 기대수명 데이터
# iris - 붓꽃(아이리스) 데이터셋으로, 머신러닝 분류 문제에서 많이 사용됨
# mpg - 자동차 연비(Miles per Gallon)와 관련된 데이터
# penguins - 펭귄의 종(species), 부리 길이, 몸무게 등의 정보를 포함한 데이터
# planets - 외계 행성(Exoplanet) 데이터
# seaice - 해빙(sea ice) 변화량과 관련된 데이터
# taxis - 뉴욕시 택시 운행 정보(거리, 요금 등)를 포함한 데이터
# tips - 팁(Tip)과 관련된 데이터 (식당에서 결제 금액, 팁 비율 등 포함)
# titanic - 타이타닉호 승객 생존 여부 데이터

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# OS에 사용가능한, 설치된 폰트 나열
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm
fontlist = fm.findSystemFonts(fontpaths=None,fontext='ttf')
fontlist
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-ExtraLight.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-Italic.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif-Italic.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-Oblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuMathTeXGyre.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Oblique.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-Oblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf']

# %%
# 리눅스용 폰트 경로 설정
plt.rc('font', family="NanumGothic")
plt.text(0.2,0.4,"한글", size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.stripplot(x='day', y='tip',hue='sex', data=tips, alpha = 0.7, ax=ax1)
sns.swarmplot(x='day',y='tip',hue='sex',data=tips, palette='Set2',alpha=0.7,ax=ax2)
ax1.set_title('Strip plot 으로 표현한 날짜별로 분류한 성별과 팁 관계')
ax2.set_title('Swarm plot 으로 표현한 날짜별로 분류한 성별과 팁 관계')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.countplot(x='time', data=tips, ax=ax1)
sns.countplot(x='day',hue='day', data=tips, palette='Set2',ax=ax2)
ax1.set_title('Countplt 시간에 따른 팁 빈도차트')
ax2.set_title('Countplt 시간과 날짜에 따른 팁 빈도차트')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x="total_bill", y="tip", data=tips, color="blue", scatter_kws={"s":50,"alpha":0.5}, line_kws=({"linestyle":"--","color":"red"}), ax=ax1)
sns.regplot(x="total_bill", y="tip", data=tips, color="blue", scatter_kws={"s":50,"alpha":0.5}, fit_reg=False, ax=ax2)

fig.suptitle("Scatter plots 선형회귀의 ON/OFF 비교")
ax1.set_title('선형회귀 ON')
ax2.set_title('선형회귀 OFF')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue="species", markers=["o","s","D"])
plt.show()

# %%
sns.boxplot(x="species",y='sepal_length',data=iris)
plt.title("")
plt.show('꽃받침 길이와 종의 관계')

# %%
sns.violinplot(x="species",y="petal_length",data=iris,hue="species",palette="muted")
plt.title("종에 따른 꽃잎의 길이 분포")
plt.show()

# %%
fig = plt.figure(figsize=(12,3))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

sns.boxplot(x="species",y="sepal_length", data=iris, ax=ax1)
sns.violinplot(x="species", y="petal_length", data=iris, hue="species", palette="muted", ax=ax2)
sns.histplot(data=iris, x="petal_length", hue="species", kde=True, element="step", palette="Set2", ax=ax3)


ax1.set_title("꽃받침 길이와 종의 관계")
ax2.set_title("종에 따른 꽃잎의 길이 분포1")
ax3.set_title("종에 따른 꽃잎의 길이 분포2")

sns.lmplot(x="sepal_length", y="sepal_width", hue="species", data=iris, markers=["o","s","D"], height=6, aspect=1.2)
plt.title("꽃받침 길이와 너비의 관계")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
exercise = sns.load_dataset('exercise')
exercise
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
# point plot
plt.figure(figsize=(10,6))
sns.pointplot(x="time",y="pulse",hue="kind",data=exercise,capsize=0.1)
plt.title("심박수와 시간별 운동종류와의 관계")
# Out:
# Text(0.5, 1.0, '심박수와 시간별 운동종류와의 관계')

# %%
# box plot
plt.figure(figsize=(7,4))
sns.boxplot(x='time',y='pulse',hue="kind",data=exercise,palette="Set2")
# Out:
# <Axes: xlabel='time', ylabel='pulse'>

# %%
# swarm plot
plt.figure(figsize=(7,4))
sns.swarmplot(x='time',y='pulse',hue='kind',data=exercise,dodge=True,palette='Set1')
plt.title("시간과 운동 유형에 따른 개별 맥박 측정")
plt.show()
