# %%
def yang(l):
    result = [] # 양수 저장할 공간
    for i in l:
        if i > 0:
            result.append(i)
    return result
print(filter(lambda x: x>0 [1,2,-3,-4,-5,6,7,8]))
# Out:
# <>:7: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:7: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1720\2659264382.py:7: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   print(filter(lambda x: x>0 [1,2,-3,-4,-5,6,7,8]))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5             result.append(i)
#       6     return result
# ----> 7 print(filter(lambda x: x>0 [1,2,-3,-4,-5,6,7,8]))
#
# TypeError: filter expected 2 arguments, got 1

# %%
add = lambda a,b: a + b
print(add(3,4))

# %%
# 06-1 구구단
def gugudan(n):
    result = []
    for i in range(1,10):
        num = n * i
        result.append(num)
    return f"{n}단: {result}"
    
#gugudan(7)

# %%
# 16진수 10진수로 바꾸기
num = hex(234)
print(int('0xea',16))

# %%
# 리스트 항목마다 3곱하여 리턴하기 - map
def mul(x):
  return x * 3

# %%
list(map(mul,([1,2,3,4])))

# %%
# 리스트 항목마다 3곱하여 리턴하기 - lambda
list(map(lambda x:x*2,[1,2,3,4]))

# %%
# 최댓값과 최솟값의 합
a = [-8,2,7,5,-3,5,0,1]
max(a)
min(a)

# %%
# 소수점 반올림하기
num = 17/3
round(num,4)

# %%
# 디렉터리 이동하고 파일 목록 출력하기

# %%
## 숫자 총합 구하기
numIn = input("숫자를 입력하시오: ")
num = numIn.split(",")
print(type(num))
result = 0
for i in num:
    result += int(i)
print(result)

# %%
## 리스트 총합 구하기
A = [20,55,67,82,45,33,90,87,100,25]
result = 0
for i in A:
    if i >= 50:
        result += i
print(result)

# %%
## 구구단 문제
num = input("몇단할지 입력: ")

# %%
import numpy as np
import pandas as pd

score_kor = {
    '홍길동':80,
    '박철수':60,
    '김영희':70
}
scoreK = pd.Series(score_kor)
#print(scoreK)
score_math = {
    '홍길동':70,
    '박철수':70,
    '김영희':90
}
scoreM = pd.Series(score_math)
#print(scoreM)
score_eng = {
    '홍길동':80,
    '박철수':80,
    '김영희':80
}
scoreE = pd.Series(score_eng)
#print(scoreE)

scoreData = pd.DataFrame({'국어':scoreK,'수학':scoreM,'영어':scoreE})
scoreData.index.name = ""
scoreData.columns.name = "이름"

scoreData

# %%
scoreData.iloc[1:2:,0:2]

# %%
scoreData[scoreData['수학']>=70]

# %%
avg = (scoreData['국어'] + scoreData['수학'] + scoreData['영어']) / 3
scoreData['평균'] = avg
scoreData

# %%
박자바 = pd.Series(data = [55,95,70], index=['국어','수학','영어'])
scoreData.loc['박자바'] = 박자바
avg = (scoreData['국어'] + scoreData['수학'] + scoreData['영어']) / 3
scoreData['평균'] = avg
scoreData

# %%
#!pip install openpyxl

# %%
import pandas as pd
file_path = "./ref/행정동별 지하철 승객수.xlsx"
df = pd.read_excel(file_path, engine="openpyxl")
df
# Out:
#              일시        행정동      전체  0시~7시  7시~8시  8시~9시 9시~12시 12시~17시  \
# 0    2024-10-31   부평구 부평1동  50,354  4,440  6,180  5,459  7,475  12,324
# 1    2024-10-31     중구 운서동  36,378  2,555  2,376  2,144  4,166  11,207
# 2    2024-10-31   연수구 송도1동  23,988  1,044  1,653  1,565  1,870   6,082
# 3    2024-10-31   계양구 계양1동  23,929  3,103  4,788  3,903  4,595   4,193
# 4    2024-10-31   연수구 송도4동  22,554  1,256  1,935  1,903  2,440   6,335
# ..          ...        ...     ...    ...    ...    ...    ...     ...
# 151  2024-10-31  남동구 남촌도림동       0      0      0      0      0       0
# 152  2024-10-31   남동구 만수4동       0      0      0      0      0       0
# 153  2024-10-31   남동구 만수3동       0      0      0      0      0       0
# 154  2024-10-31   남동구 만수2동       0      0      0      0      0       0
# 155  2024-10-31    옹진군 영흥면       0      0      0      0      0       0
#
#     17시~18시 18시~19시 19시~24시
# 0     3,223   3,269   7,984
# 1     3,310   3,261   7,359
# 2     3,118   3,675   4,981
# 3       952     988   1,407
# 4     2,457   2,382   3,846
# ..      ...     ...     ...
# 151       0       0       0
# 152       0       0       0
# 153       0       0       0
# 154       0       0       0
# 155       0       0       0
#
# [156 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   일시       156 non-null    object
#  1   행정동      156 non-null    object
#  2   전체       156 non-null    object
#  3   0시~7시    156 non-null    object
#  4   7시~8시    156 non-null    object
#  5   8시~9시    156 non-null    object
#  6   9시~12시   156 non-null    object
#  7   12시~17시  156 non-null    object
#  8   17시~18시  156 non-null    object
#  9   18시~19시  156 non-null    object
#  10  19시~24시  156 non-null    object
# dtypes: object(11)
# memory usage: 13.5+ KB

# %%
df.columns
# Out:
# Index(['일시', '행정동', '전체', '0시~7시', '7시~8시', '8시~9시', '9시~12시', '12시~17시',
#        '17시~18시', '18시~19시', '19시~24시'],
#       dtype='object')

# %%
columns = ['date', 'name', 'total', '0시~7시', '7시~8시', '8시~9시', '9시~12시', '12시~17시',
       '17시~18시', '18시~19시', '19시~24시']
df.columns = columns
df = df.loc[:,: 'total']
df
# Out:
#            date       name   total
# 0    2024-10-31   부평구 부평1동  50,354
# 1    2024-10-31     중구 운서동  36,378
# 2    2024-10-31   연수구 송도1동  23,988
# 3    2024-10-31   계양구 계양1동  23,929
# 4    2024-10-31   연수구 송도4동  22,554
# ..          ...        ...     ...
# 151  2024-10-31  남동구 남촌도림동       0
# 152  2024-10-31   남동구 만수4동       0
# 153  2024-10-31   남동구 만수3동       0
# 154  2024-10-31   남동구 만수2동       0
# 155  2024-10-31    옹진군 영흥면       0
#
# [156 rows x 3 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

d2_path = './ref/D2Coding-Ver1.3.2-20180524.ttf'
fm.fontManager.addfont(d2_path)
plt.rcParams["font.family"] = "D2Coding"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 57 to 57
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1 non-null      object
#  1   name    1 non-null      object
#  2   total   1 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 32.0+ bytes

# %%
import squarify

top20 = df.iloc[:50]
plt.figure(figsize=(15, 8))
squarify.plot(sizes=top20['total'], label=top20['name'], alpha=0.7)

plt.rcParams["font.size"] = 18
plt.gca().invert_yaxis()
plt.show()

# %%
# 워드클라우드
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.font_manager as fm
from konlpy.tag import Komoran # 명사만 분리하기

# 한글 폰트 설정
font_path = "./ref/D2Coding-Ver1.3.2-20180524.ttf" #./현재 폴더

text="""
You say it's changed
Show must go on, behave
오랜만에 옛 노래해
I'm feelin' like I never left
(That's right) I never left
But you ain't know, O.K then lights, camera
Act like you know
Don't play on me, no, we're
Airbnb, you're homeless
혼비백산-해진-미-장센 (Mise-en-scène)
도레미파시도 (Now, you know it)
두껍아 두껍아 came with the troops
뜯고 맛보고 즐기고 big bang when I shoot
King in the zoo, he gotta do what I do
One of one, not of them (Mirror)
Man in the views aimin' at you
Yeah, I'm aiming at a man, and amen, achoo
Bless you, all cleaned house, fu
Golden days are still alive
외롭다는 말하지 마
내가 있는 곳, 네가 있을 곳
The place that I belong
Home sweet home
Home sick home
Well I said, I would be back
And I'd never let you go
Pick a petal off a flower
Daze you love me nope?
Well I said, I would be back
And I'd never let you go
Pick a petal off a flower
Do you love me or (stop!)
Winner, winner chicken killer, 삼계탕 dinner
하나 둘 set down (one, two, step) 'fantastic'한 팀워크
Not mini, 많이 'More'
Rock, scissors, paper, toast
This is how we do it, just do it, let's do it y'all
Work, work 월화수목금토- 일
They gon' wait til' I'm gone
So I came, I saw, I won
G just D-word is my bond
나 무대로 올라, coup d'e shit
단숨에 호흡곤란, hook catch this
아 '무제' 도 몰라? bull as shit
Whatever, now or never
Golden days are still alive
외롭다는 말하지 마
네가 있을 곳에 내가 있는 걸
The place that I belong
Home sweet home
Home sick home
Well I said, I would be back
And i'd never let you go
Pick a petal off a flower
Daze you love me nope?
Well I said, I would be back
And i'd never let you go
Pick a petal off a flower
Do you love me or (stop!)
We alike dead or alive, your life? Still life
It's so nice, I missed you a lot
You're welcome back home, wherever you are
We alike dead or alive, your life is still with me
Livin' good life, day or nights
The highlight, it's about time to 'rock-on'
Home sweet home
Home sick home
Well, I said, I would be back
And I'd never let you go
Pick a petal off a flower
Daze, you love me, nope?
Well, I said, I would be back
And I'd never let you go
Pick a petal off a flower
Do you love me or (Stop)
"""

#data = [t for t in text if bool]
komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)
print(nouns_text)


# 워드 클라우드
wordcloud = WordCloud(font_path=font_path,width=800, height=400, background_color='white').generate(nouns_text)

# 시각화
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.savefig("word1.png")
plt.show()
# Out:
# 오랜만 노래 O.K 혼비백산 해진 미 장세 도레미 파시 말 곳 곳 삼계탕 팀워크 월화 수목 금 토 일 무대 호흡곤란 무제 도 말 곳

# %%
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.font_manager as fm

# 한글 폰트 설정
font_path = "./ref/D2Coding-Ver1.3.2-20180524.ttf"

# 텍스트 데이터
text = """
You say it's changed
Show must go on, behave
오랜만에 옛 노래해
I'm feelin' like I never left
(That's right) I never left
But you ain't know, O.K then lights, camera
Act like you know
Don't play on me, no, we're
Airbnb, you're homeless
혼비백산-해진-미-장센 (Mise-en-scène)
도레미파시도 (Now, you know it)
두껍아 두껍아 came with the troops
뜯고 맛보고 즐기고 big bang when I shoot
King in the zoo, he gotta do what I do
One of one, not of them (Mirror)
Man in the views aimin' at you
Yeah, I'm aiming at a man, and amen, achoo
Bless you, all cleaned house, fu
Golden days are still alive
외롭다는 말하지 마
내가 있는 곳, 네가 있을 곳
The place that I belong
Home sweet home
Home sick home
Well I said, I would be back
And I'd never let you go
Pick a petal off a flower
Daze you love me nope?
Well I said, I would be back
And I'd never let you go
Pick a petal off a flower
Do you love me or (stop!)
Winner, winner chicken killer, 삼계탕 dinner
하나 둘 set down (one, two, step) 'fantastic'한 팀워크
Not mini, 많이 'More'
Rock, scissors, paper, toast
This is how we do it, just do it, let's do it y'all
Work, work 월화수목금토- 일
They gon' wait til' I'm gone
So I came, I saw, I won
G just D-word is my bond
나 무대로 올라, coup d'e shit
단숨에 호흡곤란, hook catch this
아 '무제' 도 몰라? bull as shit
Whatever, now or never
Golden days are still alive
외롭다는 말하지 마
네가 있을 곳에 내가 있는 걸
The place that I belong
Home sweet home
Home sick home
Well I said, I would be back
And i'd never let you go
Pick a petal off a flower
Daze you love me nope?
Well I said, I would be back
And i'd never let you go
Pick a petal off a flower
Do you love me or (stop!)
We alike dead or alive, your life? Still life
It's so nice, I missed you a lot
You're welcome back home, wherever you are
We alike dead or alive, your life is still with me
Livin' good life, day or nights
The highlight, it's about time to 'rock-on'
Home sweet home
Home sick home
Well, I said, I would be back
And I'd never let you go
Pick a petal off a flower
Daze, you love me, nope?
Well, I said, I would be back
And I'd never let you go
Pick a petal off a flower
Do you love me or (Stop)
"""

# ✅ **한글과 영어 단어만 추출**
words = re.findall(r"[a-zA-Z]+|[가-힣]+", text)
filtered_text = " ".join(words)  # 리스트를 문자열로 변환

# ✅ **워드 클라우드 생성**
wordcloud = WordCloud(font_path=font_path, width=800, height=400, background_color="white").generate(filtered_text)

# ✅ **시각화**
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # 축 제거
plt.savefig("word1.png")
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.font_manager as fm
from konlpy.tag import Komoran  

# 한글 폰트 설정
font_path = "./ref/D2Coding-Ver1.3.2-20180524.ttf"

# 텍스트 데이터
text = """
You say it's changed
Show must go on, behave
오랜만에 옛 노래해
I'm feelin' like I never left
(That's right) I never left
But you ain't know, O.K then lights, camera
Act like you know
Don't play on me, no, we're
Airbnb, you're homeless
혼비백산-해진-미-장센 (Mise-en-scène)
도레미파시도 (Now, you know it)
두껍아 두껍아 came with the troops
뜯고 맛보고 즐기고 big bang when I shoot
King in the zoo, he gotta do what I do
One of one, not of them (Mirror)
Man in the views aimin' at you
Yeah, I'm aiming at a man, and amen, achoo
Bless you, all cleaned house, fu
Golden days are still alive
외롭다는 말하지 마
내가 있는 곳, 네가 있을 곳
The place that I belong
Home sweet home
Home sick home
Well I said, I would be back
And I'd never let you go
Pick a petal off a flower
Daze you love me nope?
Well I said, I would be back
And I'd never let you go
Pick a petal off a flower
Do you love me or (stop!)
Winner, winner chicken killer, 삼계탕 dinner
하나 둘 set down (one, two, step) 'fantastic'한 팀워크
Not mini, 많이 'More'
Rock, scissors, paper, toast
This is how we do it, just do it, let's do it y'all
Work, work 월화수목금토- 일
They gon' wait til' I'm gone
So I came, I saw, I won
G just D-word is my bond
나 무대로 올라, coup d'e shit
단숨에 호흡곤란, hook catch this
아 '무제' 도 몰라? bull as shit
Whatever, now or never
Golden days are still alive
외롭다는 말하지 마
네가 있을 곳에 내가 있는 걸
The place that I belong
Home sweet home
Home sick home
Well I said, I would be back
And i'd never let you go
Pick a petal off a flower
Daze you love me nope?
Well I said, I would be back
And i'd never let you go
Pick a petal off a flower
Do you love me or (stop!)
We alike dead or alive, your life? Still life
It's so nice, I missed you a lot
You're welcome back home, wherever you are
We alike dead or alive, your life is still with me
Livin' good life, day or nights
The highlight, it's about time to 'rock-on'
Home sweet home
Home sick home
Well, I said, I would be back
And I'd never let you go
Pick a petal off a flower
Daze, you love me, nope?
Well, I said, I would be back
And I'd never let you go
Pick a petal off a flower
Do you love me or (Stop)
"""
komoran = Komoran()
kor_nouns = komoran.nouns(text)  

eng_word = [word for word in text.split() if word.isalpha() and word.isascii()]

words = kor_nouns + eng_word
textResult = " ".join(words)  # 리스트를 문자열로 변환

wordcloud = WordCloud(font_path=font_path, width=800, height=400, background_color="white").generate(textResult)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig("word1.png")
plt.show()

# %%
# 워드카운트 직접 구현
word_list = ['home', 'sweet', 'alive', '무제', '무대']
counts = {}
result = textResult.split()

counts = {word: result.count(word) for word in word_list}
print(counts)
# Out:
# {'home': 6, 'sweet': 3, 'alive': 2, '무제': 1, '무대': 1}

# %%
from collections import Counter
kor_counts = Counter(kor_nouns)
eng_counts = Counter(eng_word)
print(kor_counts)
print(eng_counts)
# Out:
# Counter({'곳': 3, '말': 2, '오랜만': 1, '노래': 1, 'O.K': 1, '혼비백산': 1, '해진': 1, '미': 1, '장세': 1, '도레미': 1, '파시': 1, '삼계탕': 1, '팀워크': 1, '월화': 1, '수목': 1, '금': 1, '토': 1, '일': 1, '무대': 1, '호흡곤란': 1, '무제': 1, '도': 1})
# Counter({'I': 22, 'you': 18, 'a': 14, 'never': 9, 'go': 7, 'back': 7, 'or': 7, 'Home': 6, 'home': 6, 'would': 6, 'be': 6, 'And': 6, 'let': 6, 'Pick': 6, 'petal': 6, 'off': 6, 'flower': 6, 'love': 6, 'me': 6, 'do': 5, 'Well': 4, 'the': 3, 'are': 3, 'still': 3, 'The': 3, 'sweet': 3, 'sick': 3, 'Do': 3, 'is': 3, 'like': 2, 'left': 2, 'know': 2, 'with': 2, 'in': 2, 'of': 2, 'at': 2, 'Golden': 2, 'days': 2, 'alive': 2, 'place': 2, 'that': 2, 'belong': 2, 'Daze': 2, 'just': 2, 'shit': 2, 'We': 2, 'alike': 2, 'dead': 2, 'your': 2, 'life': 2, 'You': 1, 'say': 1, 'changed': 1, 'Show': 1, 'must': 1, 'behave': 1, 'But': 1, 'then': 1, 'camera': 1, 'Act': 1, 'play': 1, 'on': 1, 'homeless': 1, 'came': 1, 'troops': 1, 'big': 1, 'bang': 1, 'when': 1, 'shoot': 1, 'King': 1, 'he': 1, 'gotta': 1, 'what': 1, 'One': 1, 'not': 1, 'them': 1, 'Man': 1, 'views': 1, 'aiming': 1, 'and': 1, 'achoo': 1, 'Bless': 1, 'all': 1, 'cleaned': 1, 'fu': 1, 'winner': 1, 'chicken': 1, 'dinner': 1, 'set': 1, 'down': 1, 'Not': 1, 'toast': 1, 'This': 1, 'how': 1, 'we': 1, 'it': 1, 'work': 1, 'They': 1, 'wait': 1, 'gone': 1, 'So': 1, 'won': 1, 'G': 1, 'my': 1, 'bond': 1, 'coup': 1, 'hook': 1, 'catch': 1, 'this': 1, 'bull': 1, 'as': 1, 'now': 1, 'Still': 1, 'so': 1, 'missed': 1, 'lot': 1, 'welcome': 1, 'wherever': 1, 'good': 1, 'day': 1, 'nights': 1, 'about': 1, 'time': 1, 'to': 1})
